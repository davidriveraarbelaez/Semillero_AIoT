# %% [markdown]
# <a href="https://colab.research.google.com/github/davidriveraarbelaez/Semillero_AIoT/blob/main/EDA_ejercicio_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Paso 1: Importar librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Paso 2: Cargar datos
df = pd.read_csv('/content/ventas.csv')

# %%
# Paso 3: Exploración inicial
#print(df.tail())
#print(df.info())
print(df.describe())
# Out:
#             precio  cantidad_vendida
# count   200.000000        200.000000
# mean    804.083100         10.200000
# std     451.698688          5.628356
# min      29.760000          1.000000
# 25%     437.497500          5.000000
# 50%     857.845000         10.000000
# 75%    1222.660000         15.000000
# max    1496.630000         19.000000

# %%
# Paso 4: Detección de valores nulos
print(df.isnull().sum())
# Out:
# producto            0
# categoria           0
# precio              0
# cantidad_vendida    0
# fecha_venta         0
# dtype: int64

# %%
# Paso 5: Estadísticas básicas
print(df['precio'].mean())
print(df['producto'].value_counts())
# Out:
# 804.0831
# producto
# Pesas              15
# Lego               15
# Tablet             14
# Cafetera           14
# Raqueta            13
# Refrigerador       11
# Auriculares        10
# Smartphone         10
# Aspiradora         10
# Chaqueta           10
# Carrito             9
# Pantalón            9
# Laptop              9
# Camisa              9
# Balón de fútbol     8
# Puzzle              8
# Bicicleta           7
# Microondas          7
# Muñeca              6
# Zapatos             6
# Name: count, dtype: int64

# %%
# Paso 6: Visualización
sns.histplot(df['precio'], kde=True)
plt.title('Distribución de Precios')
plt.show()

# %%
sns.boxplot(x='categoria', y='precio', data=df)
plt.title('Precio por Categoría')
plt.show()
